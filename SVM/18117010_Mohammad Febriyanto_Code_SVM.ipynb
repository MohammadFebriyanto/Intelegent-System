# %%
import operator
import numpy as np
import matplotlib.pyplot as plt


from sklearn.svm import SVR

# %%
test_filename="II4035-regresi-test.csv"
train_filename="II4035-regresi-train.csv"

training=np.genfromtxt(train_filename,delimiter=',',skip_header=1)
test    =np.genfromtxt(test_filename,delimiter=',',skip_header=1)

# %%
train_x=training[:,1]
train_y=training[:,2]
test=test[:,1]

# %%
x = train_x[:, np.newaxis]
y = train_y[:, np.newaxis]
test = test[:, np.newaxis]

# %%
# Underfit
model = SVR(gamma=0.0001)
model.fit(x, y)
y_poly_pred = model.predict(x)
    
plt.scatter(x, y, s=30)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# /home/febriyanto/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Overfit
model = SVR(gamma=9999)
model.fit(x, y)
y_poly_pred = model.predict(x)
    
plt.scatter(x, y, s=30)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# /home/febriyanto/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#OPTIMUM
model = SVR(gamma=15)
model.fit(x, y)
y_poly_pred = model.predict(x)
    
plt.scatter(x, y, s=30)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# /home/febriyanto/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
test = test[:,1]
test = test[:, np.newaxis]
predicted = model.predict(test)

from numpy import asarray
from numpy import savetxt
# define data
data = predicted
# save to csv file
savetxt('hasilprediksi_PolynomialRegression.csv', data, delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-c3e5b5a4b0b0> in <module>()
# ----> 1 test = test[:,1]
#       2 test = test[:, np.newaxis]
#       3 predicted = model.predict(test)
#       4
#       5 from numpy import asarray
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
